# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy  import stats

# %%
x = np.linspace(-15,15,15)
stats.kstest(x,'norm')
# Out:
# KstestResult(statistic=0.45060438106283834, pvalue=0.0026758337833779366)

# %%
np.random.seed(958433524)
stats.kstest('norm',False,N=100)
sns.kdeplot(x)
plt.show()
